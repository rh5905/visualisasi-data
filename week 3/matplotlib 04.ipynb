# %% [markdown]
# # Import modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.8.4
# 1.26.4

# %% [markdown]
# # Sample Data

# %%
mu, sigma = 100, 15 # nilai mean dan nilai standard deviation

x = mu + sigma * np.random.randn(10000) # normal distribution
x
# Out:
# array([119.51841464, 104.89732516,  89.95823628, ...,  80.23911604,
#         86.09260624,  99.25379133])

# %%
x.shape
# Out:
# (10000,)

# %% [markdown]
# # Histogram dengan pyplot style

# %%
plt.hist(x, 
         bins=50, 
         facecolor='g', 
         alpha=0.75)

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Histogram')

plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()

plt.show()

# %%
plt.hist(x, 
         bins=50, 
         facecolor='y', 
         alpha=0.75)

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Histogram')

plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()

plt.show()

# %%
plt.hist(x, 
         bins=50, 
         facecolor='y', 
         alpha=0.25)

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Histogram')

plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()

plt.show()

# %%
plt.hist(x, 
         bins=50, 
         facecolor='g', 
         alpha=0.50)

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Histogram')

plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()

plt.show()

# %%
plt.hist(x,
        bins=50,
        facecolor='g',
        alpha=0.75)

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Histogram')

plt.text(45,500,r'String bebas')
plt.grid()

plt.show()

# %%
plt.hist(x,
        bins=50,
        facecolor='r',
        alpha=0.50)

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Histogram')

plt.text(45,500,r'$\mu=100,\ \sigma=15$')
plt.grid()

plt.show()

# %% [markdown]
# # Histogram dengan OO Style

# %%
fig, ax = plt.subplots()

ax.hist(x, 
        bins=50, 
        facecolor='b', 
        alpha=0.25)

ax.set_xlabel('Sumbu X')
ax.set_ylabel('Sumbu Y')
ax.set_title('Contoh Histogram')

ax.text(45, 500, r'$\mu=100,\ \sigma=15$')
ax.grid()

plt.show()
